# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\skbroadband\anaconda3\lib\site-packages (0.12.16)
# Requirement already satisfied: six>=1.5.2 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (1.11.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (3.12)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (2.7.3)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (2.10)
# Requirement already satisfied: numpy>=1.7.1 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (1.14.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (17.1)
# Requirement already satisfied: tornado>=4.3 in c:\users\skbroadband\anaconda3\lib\site-packages (from bokeh) (5.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\skbroadband\anaconda3\lib\site-packages (from Jinja2>=2.7->bokeh) (1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\skbroadband\anaconda3\lib\site-packages (from packaging>=16.8->bokeh) (2.2.0)

# %%
from bokeh.plotting import figure

# %%
from bokeh.io import output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b10ac2da-7c54-4eda-b07b-5935f810428a">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# %%
x = [1,2,3,4]
y1, y2 = [4,3,2,1], [1,2,3,4]

# %%
p.line(x, y1, legend="Y1", line_width=5, line_color='blue')
p.line(x, y2, legend="Y2", line_width=2, line_color='red')
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='0bcabddc-6498-4d67-9caf-705eaf96fb6b',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='291b606c-2a6a-4971-a965-62ab36734190',
#         callback=None,
#         data={'y': [1, 2, 3, 4], 'x': [1, 2, 3, 4]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='cd906070-20ea-46e8-ba91-5b71eb2a8687',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='ac67b409-9119-452b-89a4-28adc0e087a1',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Line(
#         id='41e2a0d2-3fa1-4784-b7e2-b8d98dc565fd',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=1.0,
#         line_cap='butt',
#         line_color='red',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width=2,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Line(
#         id='542e2157-fad0-4a1c-b17a-57fbc1c42a4f',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=0.1,
#         line_cap='butt',
#         line_color='#1f77b4',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width=2,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='c10623e9-04ea-4298-bd54-2ac8ff640dda',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='291b606c-2a6a-4971-a965-62ab36734190',
#             callback=None,
#             data={'y': [1, 2, 3, 4], 'x': [1, 2, 3, 4]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='cd906070-20ea-46e8-ba91-5b71eb2a8687',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='ac67b409-9119-452b-89a4-28adc0e087a1',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6b354a51-7fe8-4b81-8886-b24580be012b"></div>
# </div>
